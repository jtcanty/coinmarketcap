# %%
import core

# %run core.py --csv-file my_csv.csv

# %%
with open('/home/john/market_data.txt') as fp:
        data = pd.read_json(fp)

# %%
data
# Out:
#     24h_volume_usd  available_supply                    id  last_updated  \
# 0       8796450000          16854162               bitcoin    1518157466
# 1       3349270000          97502350              ethereum    1518157453
# 2        945948000       39009215838                ripple    1518157441
# 3       2081210000          16957550          bitcoin-cash    1518157452
# 4        345651000       25927070538               cardano    1518157454
# 5        768141000          55136083              litecoin    1518157441
# 6        505800000          65000000                   neo    1518157447
# 7        136074000       18432173792               stellar    1518157443
# 8        508224000         657648800                   eos    1518157451
# 9         52621100        2779530283                  iota    1518157450
# 10        43368100        8999999999                   nem    1518157444
# 11        90942000           7873310                  dash    1518157442
# ...
